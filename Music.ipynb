# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("MusicData.csv")

# %%
df.head()
# Out:
#    index Format Metric  Year  Number of Records  Value (Actual)
# 0      0     CD  Units  1973                  1             NaN
# 1      1     CD  Units  1974                  1             NaN
# 2      2     CD  Units  1975                  1             NaN
# 3      3     CD  Units  1976                  1             NaN
# 4      4     CD  Units  1977                  1             NaN

# %%
df.tail(15)
# Out:
#       index        Format            Metric  Year  Number of Records  \
# 2993   2993  Vinyl Single  Value (Adjusted)  2005                  1
# 2994   2994  Vinyl Single  Value (Adjusted)  2006                  1
# 2995   2995  Vinyl Single  Value (Adjusted)  2007                  1
# 2996   2996  Vinyl Single  Value (Adjusted)  2008                  1
# 2997   2997  Vinyl Single  Value (Adjusted)  2009                  1
# 2998   2998  Vinyl Single  Value (Adjusted)  2010                  1
# 2999   2999  Vinyl Single  Value (Adjusted)  2011                  1
# 3000   3000  Vinyl Single  Value (Adjusted)  2012                  1
# 3001   3001  Vinyl Single  Value (Adjusted)  2013                  1
# 3002   3002  Vinyl Single  Value (Adjusted)  2014                  1
# 3003   3003  Vinyl Single  Value (Adjusted)  2015                  1
# 3004   3004  Vinyl Single  Value (Adjusted)  2016                  1
# 3005   3005  Vinyl Single  Value (Adjusted)  2017                  1
# 3006   3006  Vinyl Single  Value (Adjusted)  2018                  1
# 3007   3007  Vinyl Single  Value (Adjusted)  2019                  1
#
#       Value (Actual)
# 2993       17.279429
# 2994       12.554585
# 2995        4.933082
# 2996        3.443544
# 2997        2.979171
# 2998        2.696606
# 2999        5.228183
# 3000        5.281477
# 3001        3.269213
# 3002        5.938887
# 3003        6.205390
# 3004        5.198931
# 3005        6.339678
# 3006        5.386197
# 3007        6.795946

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3008 entries, 0 to 3007
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   index              3008 non-null   int64
#  1   Format             3008 non-null   object
#  2   Metric             3008 non-null   object
#  3   Year               3008 non-null   int64
#  4   Number of Records  3008 non-null   int64
#  5   Value (Actual)     1351 non-null   float64
# dtypes: float64(1), int64(3), object(2)
# memory usage: 141.1+ KB

# %%
df.describe()
# Out:
#             index         Year  Number of Records  Value (Actual)
# count  3008.00000  3008.000000             3008.0     1351.000000
# mean   1503.50000  1996.000000                1.0      781.291237
# std     868.47913    13.566915                0.0     2246.837672
# min       0.00000  1973.000000                1.0       -7.650944
# 25%     751.75000  1984.000000                1.0        3.700228
# 50%    1503.50000  1996.000000                1.0       63.900000
# 75%    2255.25000  2008.000000                1.0      448.900000
# max    3007.00000  2019.000000                1.0    19667.327786

# %%
len(df)
# Out:
# 3008

# %%
df["Format"].unique()
# Out:
# array(['CD', 'CD Single', 'Cassette', 'Cassette Single', 'LP/EP',
#        'Vinyl Single', '8 - Track', 'Other Tapes',
#        'Music Video (Physical)', 'DVD Audio', 'SACD', 'Download Single',
#        'Download Album', 'Kiosk', 'Download Music Video',
#        'Ringtones & Ringbacks', 'Paid Subscriptions',
#        'Limited Tier Paid Subscription',
#        'On-Demand Streaming (Ad-Supported)',
#        'Other Ad-Supported Streaming', 'Other Digital',
#        'Paid Subscription', 'SoundExchange Distributions',
#        'Synchronization'], dtype=object)

# %%
df["Format"].nunique()
# Out:
# 24

# %%
df["Metric"].unique()
# Out:
# array(['Units', 'Value', 'Value (Adjusted)'], dtype=object)

# %%
df["Metric"].nunique()
# Out:
# 3

# %%
df.head()
# Out:
#    index Format Metric  Year  Number of Records  Value (Actual)
# 0      0     CD  Units  1973                  1             NaN
# 1      1     CD  Units  1974                  1             NaN
# 2      2     CD  Units  1975                  1             NaN
# 3      3     CD  Units  1976                  1             NaN
# 4      4     CD  Units  1977                  1             NaN

# %%
yearly_mean=df.groupby("Year")["Value (Actual)"].mean()

# %%
yearly_mean.head()
# Out:
# Year
# 1973     949.630970
# 1974     946.711539
# 1975     951.461691
# 1976    1041.783017
# 1977    1459.080256
# Name: Value (Actual), dtype: float64

# %%
yearly_mean.tail()
# Out:
# Year
# 2015    331.011047
# 2016    320.519459
# 2017    361.239863
# 2018    394.231973
# 2019    445.820923
# Name: Value (Actual), dtype: float64

# %%
yearly_mean.std()
# Out:
# np.float64(426.61530651521304)

# %%
yearly_mean.max()
# Out:
# np.float64(1657.6667957487825)

# %%
yearly_mean.min()
# Out:
# np.float64(320.5194594505769)

# %%
yearly_mean.var()
# Out:
# np.float64(182000.61975306916)

# %%
yearly_mean.sort_values(ascending =False)
# Out:
# Year
# 1999    1657.666796
# 1978    1619.793357
# 2000    1594.287116
# 1998    1580.017487
# 1995    1482.642970
# 1996    1482.343671
# 1994    1478.651181
# 1977    1459.080256
# 1997    1425.736334
# 1979    1330.875062
# 2001    1328.668171
# 1993    1251.181440
# 1981    1213.417426
# 1980    1211.915118
# 2002    1207.691940
# 1986    1148.740563
# 1992    1146.225361
# 1984    1119.613597
# 1987    1105.411282
# 1985    1098.369691
# 2003    1078.658523
# 1982    1063.064081
# 1976    1041.783017
# 1988    1026.678621
# 1991    1014.806330
# 1990    1006.853984
# 1983    1005.533781
# 1975     951.461691
# 1973     949.630970
# 1974     946.711539
# 1989     910.938440
# 2004     857.458324
# 2005     618.384674
# 2006     588.833144
# 2007     534.196710
# 2019     445.820923
# 2008     440.030537
# 2018     394.231973
# 2009     387.629726
# 2012     361.694878
# 2017     361.239863
# 2013     357.787853
# 2010     353.741273
# 2011     341.485160
# 2014     334.742309
# 2015     331.011047
# 2016     320.519459
# Name: Value (Actual), dtype: float64

# %%
yearly_mean.sort_values(ascending =False).head(3)
# Out:
# Year
# 1999    1657.666796
# 1978    1619.793357
# 2000    1594.287116
# Name: Value (Actual), dtype: float64

# %%
sns.barplot(x=yearly_mean.index, y=yearly_mean.values)
plt.title("Mean value per year")
plt.xlabel("Year")
plt.ylabel("mean value")
plt.show()

# %%
yearly_mean=df.groupby("Year")

# %%
df.groupby("Year")["Value (Actual)"].mean().sort_values(ascending=False).head(15)
# Out:
# Year
# 1999    1657.666796
# 1978    1619.793357
# 2000    1594.287116
# 1998    1580.017487
# 1995    1482.642970
# 1996    1482.343671
# 1994    1478.651181
# 1977    1459.080256
# 1997    1425.736334
# 1979    1330.875062
# 2001    1328.668171
# 1993    1251.181440
# 1981    1213.417426
# 1980    1211.915118
# 2002    1207.691940
# Name: Value (Actual), dtype: float64

# %%
df.groupby("Year")["Value (Actual)"].mean().sort_values(ascending=False).tail(4)
# Out:
# Year
# 2011    341.485160
# 2014    334.742309
# 2015    331.011047
# 2016    320.519459
# Name: Value (Actual), dtype: float64

# %%
df["Format"].value_counts()
# Out:
# Format
# CD                                    141
# CD Single                             141
# Cassette                              141
# Cassette Single                       141
# LP/EP                                 141
# Vinyl Single                          141
# 8 - Track                             141
# Other Tapes                           141
# Music Video (Physical)                141
# DVD Audio                             141
# SACD                                  141
# Download Single                       141
# Download Album                        141
# Kiosk                                 141
# Download Music Video                  141
# Ringtones & Ringbacks                 141
# Paid Subscriptions                     94
# Limited Tier Paid Subscription         94
# On-Demand Streaming (Ad-Supported)     94
# Other Ad-Supported Streaming           94
# Other Digital                          94
# Paid Subscription                      94
# SoundExchange Distributions            94
# Synchronization                        94
# Name: count, dtype: int64

# %%
df["Format"].value_counts().head(3)
# Out:
# Format
# CD           141
# CD Single    141
# Cassette     141
# Name: count, dtype: int64

# %%
df.sort_values("Year")
# Out:
#       index                              Format            Metric  Year  \
# 1598   1598                         Other Tapes             Value  1973
# 1645   1645                   Paid Subscription             Value  1973
# 1692   1692               Ringtones & Ringbacks             Value  1973
# 2726   2726                   Paid Subscription  Value (Adjusted)  1973
# 1457   1457  On-Demand Streaming (Ad-Supported)             Value  1973
# ...     ...                                 ...               ...   ...
# 328     328                           8 - Track             Units  2019
# 140     140                            Cassette             Units  2019
# 187     187                     Cassette Single             Units  2019
# 93       93                           CD Single             Units  2019
# 46       46                                  CD             Units  2019
#
#       Number of Records  Value (Actual)
# 1598                  1       15.600000
# 1645                  1             NaN
# 1692                  1             NaN
# 2726                  1             NaN
# 1457                  1             NaN
# ...                 ...             ...
# 328                   1             NaN
# 140                   1             NaN
# 187                   1             NaN
# 93                    1        0.026257
# 46                    1       46.506496
#
# [3008 rows x 6 columns]

# %%
df_sorted=df.sort_values("Year")

# %%
df_sorted
# Out:
#       index                              Format            Metric  Year  \
# 1598   1598                         Other Tapes             Value  1973
# 1645   1645                   Paid Subscription             Value  1973
# 1692   1692               Ringtones & Ringbacks             Value  1973
# 2726   2726                   Paid Subscription  Value (Adjusted)  1973
# 1457   1457  On-Demand Streaming (Ad-Supported)             Value  1973
# ...     ...                                 ...               ...   ...
# 328     328                           8 - Track             Units  2019
# 140     140                            Cassette             Units  2019
# 187     187                     Cassette Single             Units  2019
# 93       93                           CD Single             Units  2019
# 46       46                                  CD             Units  2019
#
#       Number of Records  Value (Actual)
# 1598                  1       15.600000
# 1645                  1             NaN
# 1692                  1             NaN
# 2726                  1             NaN
# 1457                  1             NaN
# ...                 ...             ...
# 328                   1             NaN
# 140                   1             NaN
# 187                   1             NaN
# 93                    1        0.026257
# 46                    1       46.506496
#
# [3008 rows x 6 columns]

# %%
plt.plot(df_sorted["Year"],df_sorted["Value (Actual)"],marker="o")
plt.title("Value over Time")
plt.xlabel("Year")
plt.ylabel("Value (Actual)")
plt. grid(True)
plt.show()

# %%
df.groupby("Format")["Value (Actual)"].sum()
# Out:
# Format
# 8 - Track                              30159.456658
# CD                                    525411.020874
# CD Single                               4353.296903
# Cassette                              157208.102797
# Cassette Single                         7227.226130
# DVD Audio                                153.856707
# Download Album                         25107.065340
# Download Music Video                     724.891335
# Download Single                        45894.155285
# Kiosk                                    127.936032
# LP/EP                                 127648.807493
# Limited Tier Paid Subscription          4919.177543
# Music Video (Physical)                 18437.062493
# On-Demand Streaming (Ad-Supported)      8136.506182
# Other Ad-Supported Streaming            1712.156423
# Other Digital                            152.970122
# Other Tapes                              280.680841
# Paid Subscription                      42514.172158
# Paid Subscriptions                       351.436772
# Ringtones & Ringbacks                  13499.361820
# SACD                                     183.741586
# SoundExchange Distributions            14331.814033
# Synchronization                         4934.390576
# Vinyl Single                           22055.175244
# Name: Value (Actual), dtype: float64

# %%
df.groupby("Metric")["Value (Actual)"].max()
# Out:
# Metric
# Units                1402.739373
# Value               13214.500000
# Value (Adjusted)    19667.327786
# Name: Value (Actual), dtype: float64

# %%
df.groupby(["Year","Format"])["Value (Actual)"].mean()
# Out:
# Year  Format
# 1973  8 - Track                      1131.893941
#       CD                                     NaN
#       CD Single                              NaN
#       Cassette                        176.203694
#       Cassette Single                        NaN
#                                         ...
# 2019  Ringtones & Ringbacks            17.153081
#       SACD                              0.294753
#       SoundExchange Distributions     908.200000
#       Synchronization                 276.262360
#       Vinyl Single                      4.642671
# Name: Value (Actual), Length: 1128, dtype: float64

# %%
df.groupby(["Year","Format"])

# %%
sns.boxplot(x="Format",y="Value (Actual)", data=df.head(300))
plt.title("distribution of value by format")
plt.xlabel("Format")
plt.ylabel("Value")
plt.show()

# %%
df.columns
# Out:
# Index(['index', 'Format', 'Metric', 'Year', 'Number of Records',
#        'Value (Actual)'],
#       dtype='object')

# %%
sns.pairplot(df,vars=["Year","Number of Records","Value (Actual)"],hue="Format")
plt.suptitle("Pairplot of Year,Number of Records and Value by Format",y=1.02)
plt.show()

# %%
year_metric_sum=df.groupby(["Year","Metric"])["Value (Actual)"].sum().unstack()

# %%
year_metric_sum
# Out:
# Metric        Units         Value  Value (Adjusted)
# Year
# 1973     616.200000   2016.600000      11611.664555
# 1974     593.900000   2199.700000      11407.073082
# 1975     533.300000   2388.500000      11350.125362
# 1976     591.600000   2737.100000      12298.045250
# 1977     698.200000   3500.800000      14769.043326
# 1978     726.200000   4131.400000      16199.713647
# 1979     682.800000   3675.500000      12943.075806
# 1980     649.000000   3682.000000      11423.896529
# 1981     623.900000   3973.900000      11176.626538
# 1982     578.000000   3628.600000       9613.233059
# 1983     572.000000   3786.400000       9719.072940
# 1984     673.900000   4334.700000      10665.990355
# 1985     649.400000   4362.500000      10365.275674
# 1986     616.600000   4640.700000      10825.067883
# 1987     706.200000   5564.000000      12521.791796
# 1988     761.900000   6254.700000      13516.972425
# 1989     806.800000   6579.500000      13565.284125
# 1990     865.700000   7541.100000      14750.841643
# 1991     801.000000   7834.200000      14705.345590
# 1992     895.500000   9024.000000      16443.683307
# 1993     955.600000  10046.600000      17774.973122
# 1994    1122.700000  12068.000000      20818.277166
# 1995    1112.700000  12320.300000      20667.788301
# 1996    1137.200000  12533.800000      20422.904440
# 1997    1063.400000  12236.800000      19491.735686
# 1998    1123.900000  13711.200000      21505.302199
# 1999    1160.600000  14584.700000      22381.036302
# 2000    1079.200000  14323.700000      21265.703664
# 2001     968.463000  13740.900000      19836.009437
# 2002     859.673000  12614.200000      17926.117451
# 2003     798.400000  11854.400000      16470.980113
# 2004     958.100000  12345.100000      16707.841348
# 2005    1304.500000  12289.900000      16088.064333
# 2006    1591.800000  11759.500000      14912.690930
# 2007    1855.100000  10650.900000      13135.442071
# 2008    1922.840000   8776.800000      10421.825787
# 2009    1830.900000   7831.000000       9331.956571
# 2010    1742.540000   7013.800000       8223.241125
# 2011    1828.610000   7135.600000       8110.048010
# 2012    1810.066869   7015.742990       7812.154524
# 2013    1703.551354   7034.608696       7720.081197
# 2014    1473.677042   6694.699421       7229.769743
# 2015    1277.103812   6710.818850       7238.585478
# 2016    1015.522493   7578.656138       8072.833260
# 2017     813.206269   8796.563892       9174.702737
# 2018     629.372316   9846.140253      10024.550008
# 2019     513.704068  11111.581493      11111.581493

# %%
year_metric_sum=df.groupby(["Year","Metric"])["Value (Actual)"].sum().unstack()

# %%
year_metric_sum.plot(kind ="bar",stacked=True)
plt.title("Total Value per Year by Metric")
plt.xlabel("Year")
plt.ylabel("Total Value")
plt.show()

# %%
format_year_avg=df.groupby(["Format","Year"])["Value (Actual)"].mean().head(200) . unstack()
format_year_avg
# Out:
# Year                    1973         1974         1975         1976  \
# Format
# 8 - Track        1131.893941  1164.636203  1149.336499  1277.171924
# CD                       NaN          NaN          NaN          NaN
# CD Single                NaN          NaN          NaN          NaN
# Cassette          176.203694   184.898853   194.832166   274.047890
# Cassette Single          NaN          NaN          NaN          NaN
#
# Year                    1977         1978         1979        1980  \
# Format
# 8 - Track        1453.238762  1599.607137  1065.441897  749.029284
# CD                       NaN          NaN          NaN         NaN
# CD Single                NaN          NaN          NaN         NaN
# Cassette          446.501030   758.273203   901.217237  997.118871
# Cassette Single          NaN          NaN          NaN         NaN
#
# Year                    1981         1982  ...         2010         2011  \
# Format                                     ...
# 8 - Track         414.438361    48.358211  ...     0.000000     0.000000
# CD                       NaN          NaN  ...  2538.753058  2288.545381
# CD Single                NaN          NaN  ...     2.433356     2.925988
# Cassette         1391.977923  1745.216465  ...     0.000000     0.000000
# Cassette Single          NaN          NaN  ...          NaN          NaN
#
# Year                    2012         2013         2014         2015  \
# Format
# 8 - Track                NaN          NaN          NaN          NaN
# CD               1817.185078  1554.748639  1277.722267  1040.256899
# CD Single           2.629721     1.919563     2.816588     0.958249
# Cassette                 NaN          NaN          NaN          NaN
# Cassette Single          NaN          NaN          NaN          NaN
#
# Year                   2016        2017        2018        2019
# Format
# 8 - Track               NaN         NaN         NaN         NaN
# CD               810.946500  749.259981  487.127384  425.175352
# CD Single          0.221769    1.051190    0.111335    0.129872
# Cassette                NaN         NaN         NaN         NaN
# Cassette Single         NaN         NaN         NaN         NaN
#
# [5 rows x 47 columns]

# %%
format_year_avg.T
# Out:
# Format    8 - Track            CD   CD Single     Cassette  Cassette Single
# Year
# 1973    1131.893941           NaN         NaN   176.203694              NaN
# 1974    1164.636203           NaN         NaN   184.898853              NaN
# 1975    1149.336499           NaN         NaN   194.832166              NaN
# 1976    1277.171924           NaN         NaN   274.047890              NaN
# 1977    1453.238762           NaN         NaN   446.501030              NaN
# 1978    1599.607137           NaN         NaN   758.273203              NaN
# 1979    1065.441897           NaN         NaN   901.217237              NaN
# 1980     749.029284           NaN         NaN   997.118871              NaN
# 1981     414.438361           NaN         NaN  1391.977923              NaN
# 1982      48.358211           NaN         NaN  1745.216465              NaN
# 1983       0.000000     20.716534         NaN  2231.995252              NaN
# 1984       0.000000    121.093545         NaN  2860.579828              NaN
# 1985       0.000000    445.849943         NaN  2826.770184              NaN
# 1986       0.000000   1050.895182         NaN  2891.475278              NaN
# 1987       0.000000   1760.699869         NaN  3343.503354              NaN
# 1988       0.000000   2252.020976   10.859562  3716.902425              NaN
# 1989       0.000000   2710.030158   -0.747742  3563.401050              NaN
# 1990       0.000000   3496.545196    6.278786  3568.940543              NaN
# 1991       0.000000   4271.056214   35.561725  3015.900678              NaN
# 1992       0.000000   5146.679046   44.860657  3053.757945              NaN
# 1993       0.000000   6175.703783   44.877256  2804.695572              NaN
# 1994       0.000000   7909.515962   54.059014  2818.777001              NaN
# 1995       0.000000   8610.419230  106.146372  2146.859898              NaN
# 1996       0.000000   8967.154106  175.759133  1745.048698              NaN
# 1997       0.000000   8820.583221  257.925989  1373.592033              NaN
# 1998       0.000000  10056.133562  201.197694  1268.479702              NaN
# 1999       0.000000  11140.842595  206.528405   938.094820              NaN
# 2000       0.000000  11258.642715  129.586593   543.797294              NaN
# 2001       0.000000  10808.992482   70.439932   310.998294              NaN
# 2002       0.000000   9987.781608   17.317894   179.682691              NaN
# 2003       0.000000   9195.447673   31.439949    91.832829              NaN
# 2004       0.000000   9235.059115   12.800326    20.325182              NaN
# 2005       0.000000   8332.347587    9.322873    10.916175              NaN
# 2006       0.000000   7292.689283    6.388226     3.030706              NaN
# 2007       0.000000   5714.234219    9.948634     2.366604              NaN
# 2008       0.000000   4112.159876    2.785334     0.689562              NaN
# 2009       0.000000   3253.992740    2.564724     0.000000              NaN
# 2010       0.000000   2538.753058    2.433356     0.000000              NaN
# 2011       0.000000   2288.545381    2.925988     0.000000              NaN
# 2012            NaN   1817.185078    2.629721          NaN              NaN
# 2013            NaN   1554.748639    1.919563          NaN              NaN
# 2014            NaN   1277.722267    2.816588          NaN              NaN
# 2015            NaN   1040.256899    0.958249          NaN              NaN
# 2016            NaN    810.946500    0.221769          NaN              NaN
# 2017            NaN    749.259981    1.051190          NaN              NaN
# 2018            NaN    487.127384    0.111335          NaN              NaN
# 2019            NaN    425.175352    0.129872          NaN              NaN

# %%
format_year_avg.T.plot(marker="o")
plt.ylabel("Average Value")
plt.xlabel("Year")
plt.show()
